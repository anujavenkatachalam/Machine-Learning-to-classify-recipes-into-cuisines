# %% [markdown]
# #### Title: Machine learning predictive models, and text analysis

# %% [markdown]
# This jupyter notebook imports the recipes.csv file, and runs all the 6 ML classification models - Logistic regression, Decision tree, Random forest, K-NN, Naive Bayes and Linear SVC to predict if a recipe is Italian, but first, we use a Tfidf vectorizer to numericize the ingredients in the recipe.

# %% [markdown]
# #### Author: Anuja Venkatachalam

# %%
# importing the requisite packages
import pandas as pd
import numpy as np

# %%
# reading in the raw file

# %%
df=pd.read_csv("recipes.csv")

# %%
df.shape
# Out:
# (39774, 3)

# %%
df.sample(5)
# Out:
#             cuisine     id                                    ingredient_list
# 13889       spanish  11833  sugar, vanilla extract, egg whites, sweetened ...
# 6788        mexican  16500  beef, garlic, onions, stock, lemon, ground cor...
# 27458      moroccan  45738  whole wheat couscous, pinenuts, flat leaf pars...
# 36837       mexican   3013  tomatoes, garlic powder, salsa, boneless skinl...
# 19383  cajun_creole   5229  ground cloves, unsalted butter, ground cardamo...

# %%
df.cuisine.value_counts()
# Out:
# italian         7838
# mexican         6438
# southern_us     4320
# indian          3003
# chinese         2673
# french          2646
# cajun_creole    1546
# thai            1539
# japanese        1423
# greek           1175
# spanish          989
# korean           830
# vietnamese       825
# moroccan         821
# british          804
# filipino         755
# irish            667
# jamaican         526
# russian          489
# brazilian        467
# Name: cuisine, dtype: int64

# %%
# creating a binary outcome variable  
df["is_italian"]=np.where(df["cuisine"]=="italian", 1,0)

# %%
# creating and testing a custom tokenizer
def custom_tokenizer(text):
    spaces=text.strip()
    lower_case=text.lower()
    split_words=text.split(",")
    return split_words

# %%
text="my, name, is, anuja"
custom_tokenizer(text)
# Out:
# ['my', ' name', ' is', ' anuja']

# %%
# sampling only 40% of the dataset to combat memory issues
df=df.sample(frac=0.40)

# %%
# vectorizing the ingredients list - setting max_features to combat memory issues
from sklearn.feature_extraction.text import TfidfVectorizer
model=TfidfVectorizer(stop_words="english",tokenizer=custom_tokenizer, use_idf=True, max_features=40)
result=model.fit_transform(df["ingredient_list"])

# %%
results_df=pd.DataFrame(result.toarray(), columns=model.get_feature_names())

# %%
results_df
# Out:
#        all-purpose flour   baking powder   black pepper    butter   carrots  \
# 0               0.000000        0.000000       0.616569  0.000000  0.000000
# 1               0.000000        0.000000       0.000000  0.000000  0.543628
# 2               0.466671        0.626052       0.000000  0.000000  0.000000
# 3               0.000000        0.000000       0.000000  0.000000  0.000000
# 4               0.000000        0.000000       0.000000  0.546495  0.000000
# 5               0.000000        0.000000       0.000000  0.000000  0.525150
# 6               0.000000        0.000000       0.558919  0.000000  0.000000
# 7               0.000000        0.000000       0.000000  0.424741  0.000000
# 8               0.000000        0.000000       0.000000  0.000000  0.000000
# 9               0.395233        0.530216       0.000000  0.000000  0.000000
# 10              0.000000        0.000000       0.000000  0.000000  0.000000
# 11              0.000000        0.000000       0.000000  0.000000  0.000000
# 12              0.489385        0.656523       0.000000  0.498421  0.000000
# 13              0.510512        0.684866       0.000000  0.519938  0.000000
# 14              0.000000        0.000000       0.000000  0.000000  0.445486
# 15              0.507875        0.000000       0.000000  0.517253  0.000000
# 16              0.000000        0.000000       0.000000  0.000000  0.000000
# 17              0.000000        0.000000       0.000000  0.000000  0.000000
# 18              0.000000        0.000000       0.000000  0.000000  0.000000
# 19              0.000000        0.000000       0.471594  0.000000  0.000000
# 20              0.000000        0.000000       0.000000  0.000000  0.514961
# 21              0.000000        0.000000       0.000000  0.000000  0.000000
# 22              0.000000        0.000000       0.000000  0.000000  0.000000
# 23              0.000000        0.000000       0.000000  0.000000  0.000000
# 24              0.000000        0.000000       0.000000  0.000000  0.000000
# 25              0.000000        0.467629       0.000000  0.000000  0.000000
# 26              0.000000        0.000000       0.000000  0.000000  0.000000
# 27              0.000000        0.000000       0.000000  0.457522  0.000000
# 28              0.000000        0.000000       0.391115  0.000000  0.000000
# 29              0.366859        0.000000       0.000000  0.000000  0.000000
# ...                  ...             ...            ...       ...       ...
# 6334            0.000000        0.000000       0.000000  0.000000  0.000000
# 6335            0.000000        0.000000       0.000000  0.000000  0.000000
# 6336            0.000000        0.000000       0.000000  0.000000  0.000000
# 6337            0.000000        0.000000       0.000000  0.000000  0.000000
# 6338            0.447789        0.000000       0.000000  0.000000  0.000000
# 6339            0.000000        0.000000       0.000000  0.000000  0.434672
# 6340            0.000000        0.000000       0.000000  0.000000  0.000000
# 6341            0.000000        0.000000       0.000000  0.000000  0.000000
# 6342            0.000000        0.000000       0.448065  0.000000  0.414042
# 6343            0.000000        0.000000       0.000000  0.000000  0.000000
# 6344            0.542979        0.000000       0.000000  0.553004  0.000000
# 6345            0.700609        0.000000       0.000000  0.713545  0.000000
# 6346            0.000000        0.000000       0.000000  0.000000  0.000000
# 6347            0.000000        0.000000       0.000000  0.000000  0.000000
# 6348            0.000000        0.000000       0.000000  0.000000  0.760885
# 6349            1.000000        0.000000       0.000000  0.000000  0.000000
# 6350            0.000000        0.000000       0.000000  0.600451  0.000000
# 6351            0.000000        0.000000       0.000000  0.000000  0.000000
# 6352            0.000000        0.000000       0.000000  0.000000  0.000000
# 6353            0.000000        0.000000       0.000000  0.000000  0.000000
# 6354            0.000000        0.000000       0.000000  0.000000  0.000000
# 6355            0.000000        0.000000       0.000000  0.000000  0.000000
# 6356            0.000000        0.000000       0.000000  0.000000  0.000000
# 6357            0.000000        0.000000       0.000000  0.000000  0.000000
# 6358            0.000000        0.000000       0.000000  0.000000  0.506898
# 6359            0.000000        0.000000       0.000000  0.000000  0.000000
# 6360            0.000000        0.000000       0.000000  0.000000  0.000000
# 6361            0.000000        0.000000       0.000000  0.000000  0.000000
# 6362            0.000000        0.000000       0.000000  0.000000  0.000000
# 6363            0.000000        0.000000       0.000000  0.000000  0.000000
#
#        chili powder   chopped cilantro fresh   corn starch   dried oregano  \
# 0          0.000000                 0.000000      0.000000        0.000000
# 1          0.000000                 0.000000      0.000000        0.000000
# 2          0.000000                 0.000000      0.000000        0.000000
# 3          0.000000                 0.000000      0.000000        0.000000
# 4          0.000000                 0.000000      0.000000        0.000000
# 5          0.000000                 0.000000      0.000000        0.000000
# 6          0.000000                 0.000000      0.000000        0.579479
# 7          0.000000                 0.000000      0.000000        0.000000
# 8          0.000000                 0.000000      0.000000        0.000000
# 9          0.000000                 0.000000      0.000000        0.000000
# 10         0.496242                 0.000000      0.000000        0.000000
# 11         0.000000                 0.000000      0.000000        0.000000
# 12         0.000000                 0.000000      0.000000        0.000000
# 13         0.000000                 0.000000      0.000000        0.000000
# 14         0.000000                 0.000000      0.000000        0.000000
# 15         0.000000                 0.000000      0.000000        0.000000
# 16         0.000000                 0.000000      0.000000        0.000000
# 17         0.000000                 0.000000      0.000000        0.000000
# 18         0.734264                 0.000000      0.000000        0.000000
# 19         0.480740                 0.000000      0.000000        0.000000
# 20         0.000000                 0.000000      0.000000        0.000000
# 21         0.000000                 0.000000      0.000000        0.000000
# 22         0.000000                 0.000000      0.000000        0.000000
# 23         0.000000                 0.000000      0.000000        0.000000
# 24         0.000000                 0.000000      0.000000        0.000000
# 25         0.000000                 0.000000      0.463090        0.000000
# 26         0.000000                 0.000000      0.000000        0.000000
# 27         0.000000                 0.000000      0.000000        0.000000
# 28         0.000000                 0.000000      0.000000        0.405502
# 29         0.000000                 0.000000      0.487374        0.000000
# ...             ...                      ...           ...             ...
# 6334       0.000000                 0.000000      0.000000        0.000000
# 6335       0.000000                 0.000000      0.000000        0.000000
# 6336       0.000000                 0.000000      0.000000        0.000000
# 6337       0.000000                 0.000000      0.000000        0.000000
# 6338       0.000000                 0.000000      0.000000        0.000000
# 6339       0.479513                 0.496483      0.000000        0.000000
# 6340       0.000000                 0.000000      0.000000        0.000000
# 6341       0.000000                 0.000000      0.000000        0.000000
# 6342       0.000000                 0.000000      0.000000        0.000000
# 6343       0.000000                 0.000000      0.000000        0.000000
# 6344       0.000000                 0.000000      0.000000        0.000000
# 6345       0.000000                 0.000000      0.000000        0.000000
# 6346       0.000000                 0.000000      0.000000        0.000000
# 6347       0.000000                 0.000000      0.000000        0.000000
# 6348       0.000000                 0.000000      0.000000        0.000000
# 6349       0.000000                 0.000000      0.000000        0.000000
# 6350       0.000000                 0.000000      0.000000        0.000000
# 6351       0.000000                 0.000000      0.000000        0.000000
# 6352       0.000000                 0.000000      0.000000        0.000000
# 6353       0.000000                 0.000000      0.000000        0.000000
# 6354       0.000000                 0.000000      0.000000        0.000000
# 6355       0.000000                 0.000000      0.000000        0.000000
# 6356       0.000000                 0.000000      0.000000        0.000000
# 6357       0.000000                 0.000000      0.000000        0.000000
# 6358       0.000000                 0.000000      0.000000        0.000000
# 6359       0.000000                 0.000000      0.000000        0.000000
# 6360       0.000000                 0.000000      0.000000        0.000000
# 6361       0.000000                 0.000000      0.000000        0.000000
# 6362       0.000000                 0.000000      0.000000        0.000000
# 6363       0.000000                 0.000000      0.000000        0.000000
#
#           eggs  ...   scallions   sesame oil   shallots   sour cream  \
# 0     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 1     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 2     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 3     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 4     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 5     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 7     0.000000  ...         0.0     0.000000   0.567784     0.000000
# 8     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 9     0.000000  ...         0.0     0.000000   0.000000     0.000000
# 10    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 11    0.682035  ...         0.0     0.000000   0.000000     0.000000
# 12    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 13    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 14    0.000000  ...         0.0     0.494727   0.000000     0.000000
# 15    0.622266  ...         0.0     0.000000   0.000000     0.000000
# 16    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 17    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 18    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 19    0.451719  ...         0.0     0.000000   0.000000     0.000000
# 20    0.000000  ...         0.0     0.571881   0.000000     0.000000
# 21    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 22    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 23    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 24    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 25    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 26    0.000000  ...         0.0     0.000000   0.000000     0.000000
# 27    0.000000  ...         0.0     0.000000   0.611605     0.000000
# 28    0.374632  ...         0.0     0.000000   0.000000     0.000000
# 29    0.000000  ...         0.0     0.000000   0.000000     0.000000
# ...        ...  ...         ...          ...        ...          ...
# 6334  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6335  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6336  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6337  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6338  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6339  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6340  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6341  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6342  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6343  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6344  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6345  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6346  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6347  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6348  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6349  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6350  0.000000  ...         0.0     0.000000   0.000000     0.799662
# 6351  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6352  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6353  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6354  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6355  0.000000  ...         0.0     0.000000   0.000000     1.000000
# 6356  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6357  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6358  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6359  0.523634  ...         0.0     0.000000   0.000000     0.000000
# 6360  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6361  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6362  0.000000  ...         0.0     0.000000   0.000000     0.000000
# 6363  0.000000  ...         0.0     0.000000   0.000000     0.000000
#
#        soy sauce     sugar   tomatoes   unsalted butter   vegetable oil  \
# 0       0.000000  0.000000     0.0000          0.584619        0.000000
# 1       0.000000  0.000000     0.0000          0.000000        0.000000
# 2       0.000000  0.000000     0.0000          0.000000        0.000000
# 3       0.000000  0.000000     0.0000          0.000000        0.000000
# 4       0.000000  0.000000     0.0000          0.000000        0.000000
# 5       0.000000  0.000000     0.0000          0.000000        0.000000
# 6       0.000000  0.000000     0.0000          0.000000        0.000000
# 7       0.000000  0.000000     0.0000          0.000000        0.000000
# 8       0.000000  0.000000     0.0000          0.000000        0.566767
# 9       0.000000  0.000000     0.0000          0.000000        0.000000
# 10      0.000000  0.000000     0.0000          0.000000        0.000000
# 11      0.000000  0.000000     0.0000          0.000000        0.000000
# 12      0.000000  0.000000     0.0000          0.000000        0.000000
# 13      0.000000  0.000000     0.0000          0.000000        0.000000
# 14      0.452034  0.000000     0.0000          0.000000        0.000000
# 15      0.000000  0.000000     0.0000          0.000000        0.000000
# 16      0.000000  0.000000     0.0000          0.000000        0.000000
# 17      0.000000  0.000000     0.0000          0.000000        0.000000
# 18      0.000000  0.000000     0.0000          0.000000        0.000000
# 19      0.000000  0.000000     0.0000          0.447157        0.000000
# 20      0.522529  0.000000     0.0000          0.000000        0.000000
# 21      0.000000  0.000000     0.0000          0.000000        0.000000
# 22      0.000000  0.000000     0.0000          0.000000        0.000000
# 23      0.000000  0.000000     0.0000          0.000000        0.000000
# 24      0.000000  0.000000     0.0000          0.000000        0.000000
# 25      0.000000  0.351378     0.0000          0.422778        0.000000
# 26      0.000000  0.500542     0.0000          0.000000        0.000000
# 27      0.000000  0.000000     0.0000          0.000000        0.000000
# 28      0.000000  0.000000     0.0000          0.000000        0.000000
# 29      0.000000  0.369804     0.0000          0.444948        0.000000
# ...          ...       ...        ...               ...             ...
# 6334    0.000000  0.000000     0.0000          0.000000        0.000000
# 6335    0.000000  0.000000     0.0000          0.000000        0.000000
# 6336    0.734680  0.000000     0.0000          0.000000        0.000000
# 6337    1.000000  0.000000     0.0000          0.000000        0.000000
# 6338    0.000000  0.451384     0.0000          0.000000        0.000000
# 6339    0.000000  0.000000     0.0000          0.000000        0.000000
# 6340    0.000000  0.000000     0.0000          0.000000        0.000000
# 6341    0.000000  0.000000     0.0000          0.000000        0.000000
# 6342    0.420128  0.000000     0.0000          0.000000        0.000000
# 6343    0.000000  0.000000     0.0000          0.000000        0.000000
# 6344    0.000000  0.547338     0.0000          0.000000        0.000000
# 6345    0.000000  0.000000     0.0000          0.000000        0.000000
# 6346    0.000000  0.000000     0.0000          0.616196        0.000000
# 6347    0.000000  0.535284     0.0000          0.000000        0.550980
# 6348    0.000000  0.648887     0.0000          0.000000        0.000000
# 6349    0.000000  0.000000     0.0000          0.000000        0.000000
# 6350    0.000000  0.000000     0.0000          0.000000        0.000000
# 6351    0.000000  0.000000     0.0000          0.000000        0.000000
# 6352    0.000000  1.000000     0.0000          0.000000        0.000000
# 6353    0.000000  0.000000     0.0000          0.000000        0.000000
# 6354    0.000000  0.000000     0.5126          0.000000        0.000000
# 6355    0.000000  0.000000     0.0000          0.000000        0.000000
# 6356    0.000000  0.000000     0.0000          0.000000        0.000000
# 6357    0.000000  0.000000     0.0000          0.000000        0.000000
# 6358    0.000000  0.000000     0.0000          0.000000        0.000000
# 6359    0.000000  0.000000     0.0000          0.000000        0.000000
# 6360    0.000000  0.000000     0.0000          0.000000        0.000000
# 6361    0.000000  0.000000     0.0000          0.000000        0.000000
# 6362    0.000000  0.000000     0.0000          0.000000        0.000000
# 6363    0.000000  0.000000     0.0000          0.000000        0.000000
#
#          water
# 0     0.446574
# 1     0.426099
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    0.000000
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27    0.000000
# 28    0.283280
# 29    0.000000
# ...        ...
# 6334  0.000000
# 6335  0.000000
# 6336  0.000000
# 6337  0.000000
# 6338  0.414863
# 6339  0.340699
# 6340  0.000000
# 6341  0.000000
# 6342  0.324529
# 6343  0.000000
# 6344  0.000000
# 6345  0.000000
# 6346  0.470695
# 6347  0.000000
# 6348  0.000000
# 6349  0.000000
# 6350  0.000000
# 6351  0.000000
# 6352  0.000000
# 6353  0.000000
# 6354  0.000000
# 6355  0.000000
# 6356  0.000000
# 6357  0.000000
# 6358  0.000000
# 6359  0.000000
# 6360  0.000000
# 6361  0.000000
# 6362  0.000000
# 6363  0.000000
#
# [6364 rows x 40 columns]

# %%
# Creating the X and y variables
X=results_df
y=df["is_italian"]

# %%
# Splitting the dataset into train and test 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test=train_test_split(X,y,random_state=30)

# %%
# Checking the distribution of y in the training and test datasets - 
## as it is skewed - i.e., there are more 0s than 1s, the models are likely to have low sensitivity and high specificity
X_train.shape
# Out:
# (4773, 40)

# %%
X_test.shape
# Out:
# (1591, 40)

# %%
y_train.value_counts()
# Out:
# 0    3820
# 1     953
# Name: is_italian, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    3173
# 1     805
# Name: is_italian, dtype: int64

# %% [markdown]
# #### Logistic regression

# %%
from sklearn.linear_model.logistic import LogisticRegression
logit=LogisticRegression(C=1e9, solver="lbfgs",max_iter=4000)
result=logit.fit(X_train,y_train)
predictions=logit.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test, predictions)
matrix_df=pd.DataFrame(matrix, columns=["Predicted_0","Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         3053          120
# Actual_1          508          297

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"Logit(accuracy): {accuracy:.2f}%")
print(f"Logit(error_rate): {error_rate:.2f}%")
print(f"Logit(sensitivity): {sensitivity_pos:.2f}%")
print(f"Logit(specificity): {specificity_neg:.2f}%")
# Out:
# Logit(accuracy): 84.21%
# Logit(error_rate): 15.79%
# Logit(sensitivity): 36.89%
# Logit(specificity): 96.22%

# %% [markdown]
# #### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(max_depth=5)
results=tree.fit(X_train,y_train)
predictions=tree.predict(X_test)
matrix_df=pd.DataFrame(confusion_matrix(y_test,predictions), columns=["Predicted_0","Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         3057          116
# Actual_1          559          246

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"Tree(accuracy): {accuracy:.2f}%")
print(f"Tree(error_rate): {error_rate:.2f}%")
print(f"Tree(sensitivity): {sensitivity_pos:.2f}%")
print(f"Tree(specificity): {specificity_neg:.2f}%")
# Out:
# Tree(accuracy): 83.03%
# Tree(error_rate): 16.97%
# Tree(sensitivity): 30.56%
# Tree(specificity): 96.34%

# %% [markdown]
# #### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=100, max_depth = 5)
results=forest.fit(X_train,y_train)
predictions=forest.predict(X_test)
matrix_df=pd.DataFrame(confusion_matrix(y_test, predictions), columns=["Predicted_0","Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         3154           19
# Actual_1          677          128

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"Forest (accuracy): {accuracy:.2f}%")
print(f"Forest (error_rate): {error_rate:.2f}%")
print(f"Forest (sensitivity): {sensitivity_pos:.2f}%")
print(f"Forest (specificity): {specificity_neg:.2f}%")
# Out:
# Forest (accuracy): 82.50%
# Forest (error_rate): 17.50%
# Forest (sensitivity): 15.90%
# Forest (specificity): 99.40%

# %% [markdown]
# #### K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
results=knn.fit(X_train, y_train)
predictions=knn.predict(X_test)
matrix_df=pd.DataFrame(confusion_matrix(y_test,predictions), columns=["Predicted_0", "Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         2943          230
# Actual_1          481          324

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"K-NN (accuracy): {accuracy:.2f}%")
print(f"K-NN (error_rate): {error_rate:.2f}%")
print(f"K-NN (sensitivity): {sensitivity_pos:.2f}%")
print(f"K-NN (specificity): {specificity_neg:.2f}%")
# Out:
# K-NN (accuracy): 82.13%
# K-NN (error_rate): 17.87%
# K-NN (sensitivity): 40.25%
# K-NN (specificity): 92.75%

# %% [markdown]
# #### Linear SVC

# %%
from sklearn import svm
svm=svm.SVC(kernel="linear", C=1.0)
results=svm.fit(X_train, y_train)
predictions=svm.predict(X_test)
matrix_df=pd.DataFrame(confusion_matrix(y_test, predictions), columns=["Predicted_0","Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         3063          110
# Actual_1          556          249

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"Linear SVC (accuracy): {accuracy:.2f}%")
print(f"Linear SVC (error_rate): {error_rate:.2f}%")
print(f"Linear SVC (sensitivity): {sensitivity_pos:.2f}%")
print(f"Linear SVC (specificity): {specificity_neg:.2f}%")
# Out:
# Linear SVC (accuracy): 83.26%
# Linear SVC (error_rate): 16.74%
# Linear SVC (sensitivity): 30.93%
# Linear SVC (specificity): 96.53%

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
results=nb.fit(X_train, y_train)
predictions=nb.predict(X_test)
matrix_df=pd.DataFrame(confusion_matrix(y_test, predictions), columns=["Predicted_0","Predicted_1"], index=["Actual_0","Actual_1"])

# %%
matrix_df
# Out:
#           Predicted_0  Predicted_1
# Actual_0         3132           41
# Actual_1          635          170

# %%
correct=matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_1","Predicted_1"]
total=matrix_df.sum()[0]+matrix_df.sum()[1]
accuracy=correct/total*100
error_rate=100-accuracy
sensitivity_pos=matrix_df.loc["Actual_1","Predicted_1"]/(matrix_df.loc["Actual_1","Predicted_1"]+matrix_df.loc["Actual_1","Predicted_0"])*100
specificity_neg=matrix_df.loc["Actual_0","Predicted_0"]/(matrix_df.loc["Actual_0","Predicted_0"]+matrix_df.loc["Actual_0","Predicted_1"])*100

# %%
print(f"NB (accuracy): {accuracy:.2f}%")
print(f"NB (error_rate): {error_rate:.2f}%")
print(f"NB (sensitivity): {sensitivity_pos:.2f}%")
print(f"NB (specificity): {specificity_neg:.2f}%")
# Out:
# NB (accuracy): 83.01%
# NB (error_rate): 16.99%
# NB (sensitivity): 21.12%
# NB (specificity): 98.71%

# %% [markdown]
# #### Logit  has the highest accuracy, sensitivity and specificity rates, and performs the best in screening the features and predicting if a recipe has x,y,z ingredients (weighted), whether it is likely to be Italian or not.

# %% [markdown]
# #### The End!
